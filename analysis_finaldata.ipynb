# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_save = './Output/'
#df = pd.read_csv(path_save + 'finaldataset_for_ML.csv', encoding='latin-1')
df = pd.read_csv(path_save + 'finaldataset_for_ML2.csv', encoding='latin-1')

# %%
display(df)
# Out:
#          NIF_anon  ANO_EXERCICIO DATA_RECEPCAO  VENDAS_SERVICOS_PRESTADOS  \
# 0     533683393.0           2013       35:43.0                 3575292.13
# 1     833283384.0           2014       14:12.0                 4375479.08
# 2     233783340.0           2014       42:30.0                 2858042.68
# 3     533884363.0           2013       04:47.0                 3104380.30
# 4     633484313.0           2015       46:12.0                19657707.01
# ...           ...            ...           ...                        ...
# 1351   80182420.0           2020       17:01.0                       0.00
# 1352  281789489.0           2020       44:50.0                       0.00
# 1353  382488479.0           2020       36:43.0                       0.00
# 1354   82188456.0           2020       57:59.0                       0.00
# 1355  782282457.0           2020       07:18.0                       0.00
#
#       SUBSIDIOS_EXPLORACAO  GANHOS_PERDAS_SUBSIDIARIAS  \
# ...

# %%
df_anulados = df.loc[df['Anulado'] == 1, :]
df_encerrados = df.loc[df['Terminado'] == 1, :]

# %%
display(df_anulados)
# Out:
#          NIF_anon  ANO_EXERCICIO DATA_RECEPCAO  VENDAS_SERVICOS_PRESTADOS  \
# 11    833688307.0           2016       47:20.0                 7363895.17
# 14    333381322.0           2013       00:21.0                 2469363.43
# 15    433881397.0           2014       08:18.0                 2078133.36
# 18    533181305.0           2014       21:18.0                  788601.20
# 19    633882356.0           2018       40:34.0                14481549.67
# ...           ...            ...           ...                        ...
# 1351   80182420.0           2020       17:01.0                       0.00
# 1352  281789489.0           2020       44:50.0                       0.00
# 1353  382488479.0           2020       36:43.0                       0.00
# 1354   82188456.0           2020       57:59.0                       0.00
# 1355  782282457.0           2020       07:18.0                       0.00
#
#       SUBSIDIOS_EXPLORACAO  GANHOS_PERDAS_SUBSIDIARIAS  \
# ...

# %%
# Count the occurrences of each value in the column
value_counts = df_anulados['ANO_EXERCICIO'].value_counts()

# Plot the counts using Matplotlib
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Projects cancelled by year')

# Annotate bars with their values
for i, v in enumerate(value_counts.values):
    plt.text(value_counts.index[i], v + 0.2, str(v), ha='center')

plt.show()

# %%
# Count the occurrences of each value in the column
value_counts = df_encerrados['ANO_EXERCICIO'].value_counts()

# Plot the counts using Matplotlib
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Projects terminated by year')

# Annotate bars with their values
for i, v in enumerate(value_counts.values):
    plt.text(value_counts.index[i], v + 0.2, str(v), ha='center')

plt.show()

# %%
display(df_anulados[['Parametros/Ano_Cand', 'LISTA_ANO_EXERCICIO',
 'ANO_EXERCICIO_VALIDOS',
 'ANO_EXERCICIO_VALIDOS_ORIGINAL',
 'Projeto_Valido']])
# Out:
#       Parametros/Ano_Cand                               LISTA_ANO_EXERCICIO  \
# 11                 2017.0  [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 14                 2014.0              [2013, 2014, 2015, 2016, 2018, 2019]
# 15                 2015.0  [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 18                 2015.0  [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 19                 2019.0  [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# ...                   ...                                               ...
# 1351                  0.0                                            [2020]
# 1352                  0.0                                            [2020]
# 1353                  0.0                                            [2020]
# 1354                  0.0                                            [2020]
# 1355                  0.0                                            [2020]
#
# ...

# %%
def count_years_before(row):
    counter = 0
    candidate_year = int(row['Parametros/Ano_Cand'])
    years_list = row['LISTA_ANO_EXERCICIO'].strip('][').split(', ')
    for year in years_list:
        if int(year) < candidate_year:
            counter += 1
    return counter

# %%
df_anulados['NR_ANOS_VALIDOS'] = df_anulados.apply(lambda x: count_years_before(x), axis=1)
# Out:
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# ...

# %%
df_encerrados['NR_ANOS_VALIDOS'] = df_encerrados.apply(lambda x: count_years_before(x), axis=1)
# Out:
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# Comparação feita
# ...

# %%
# Count the occurrences of each value in the column
value_counts = df_encerrados['NR_ANOS_VALIDOS'].value_counts()

# Plot the counts using Matplotlib
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Number of valid years of terminated projects')

# Annotate bars with their values
for i, v in enumerate(value_counts.values):
    plt.text(value_counts.index[i], v + 0.2, str(v), ha='center')

plt.show()

# %%
df_encerrados.shape
# Out:
# (804, 438)

# %%
# Count the occurrences of each value in the column
value_counts = df_anulados['NR_ANOS_VALIDOS'].value_counts()

# Plot the counts using Matplotlib
plt.bar(value_counts.index, value_counts.values)
plt.xlabel('Value')
plt.ylabel('Count')
plt.title('Number of valid years of cancelled projects')

# Annotate bars with their values
for i, v in enumerate(value_counts.values):
    plt.text(value_counts.index[i], v + 0.2, str(v), ha='center')

plt.show()

# %%
df_anulados.shape
# Out:
# (552, 438)

# %%
df_anulados['Parametros/Ano_Cand'].unique()
# Out:
# array([2017., 2014., 2015., 2019., 2016., 2018., 2021.,    0.])

# %%
display(df_anulados.loc[df_anulados['NR_ANOS_VALIDOS'] == 1, ['ANO_EXERCICIO', 'Parametros/Ano_Cand', 'LISTA_ANO_EXERCICIO',]])
# Out:
#       ANO_EXERCICIO  Parametros/Ano_Cand  \
# 14             2013               2014.0
# 30             2013               2014.0
# 33             2013               2014.0
# 42             2013               2014.0
# 45             2013               2014.0
# ...             ...                  ...
# 1189           2017               2018.0
# 1193           2018               2019.0
# 1194           2018               2019.0
# 1195           2018               2019.0
# 1196           2020               2021.0
#
#                                    LISTA_ANO_EXERCICIO
# 14                [2013, 2014, 2015, 2016, 2018, 2019]
# 30    [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 33    [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 42    [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# 45    [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]
# ...                                                ...
# 1189                          [2017, 2018, 2019, 2020]
# ...

# %%
df_encerrados['NR_ANOS_VALIDOS'].unique()
# Out:
# array([1, 2, 3, 4, 5, 7, 0], dtype=int64)

# %%
display(df_encerrados)
# Out:
#          NIF_anon  ANO_EXERCICIO DATA_RECEPCAO  VENDAS_SERVICOS_PRESTADOS  \
# 0     533683393.0           2013       35:43.0                 3575292.13
# 1     833283384.0           2014       14:12.0                 4375479.08
# 2     233783340.0           2014       42:30.0                 2858042.68
# 3     533884363.0           2013       04:47.0                 3104380.30
# 4     633484313.0           2015       46:12.0                19657707.01
# ...           ...            ...           ...                        ...
# 1305  274683414.0           2016       32:49.0                       0.00
# 1310  874384403.0           2016       00:43.0                       0.00
# 1316  275484418.0           2017       09:24.0                       0.00
# 1325  577485425.0           2017       21:48.0                       0.00
# 1335  170487472.0           2018       31:29.0                       0.00
#
#       SUBSIDIOS_EXPLORACAO  GANHOS_PERDAS_SUBSIDIARIAS  \
# ...
